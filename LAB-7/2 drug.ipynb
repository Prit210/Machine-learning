# %%
import pandas as pd
import numpy as np
from collections import Counter
import math
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
def entropy(labels):
    counts = Counter(labels)
    total = len(labels)
    ent = 0.0
    for v in counts.values():
        p = v/total
        ent -= p * math.log2(p)
    return ent

# %%
def information_gain(X_col, y):
    base_entropy = entropy(y)
    values = set(X_col)
    total = len(y)
    weighted_entropy = 0
    for v in values:
        subset_y = [y[i] for i in range(total) if X_col[i] == v]
        weighted_entropy += (len(subset_y)/total) * entropy(subset_y)
    return base_entropy - weighted_entropy

# %%
def gain_ratio(X_col, y):
    ig = information_gain(X_col, y)
    values = set(X_col)
    total = len(y)
    split_info = -sum((list(X_col).count(v)/total) * math.log2(list(X_col).count(v)/total) for v in values)
    return ig / split_info if split_info != 0 else 0

# %%
def id3(X, y, attributes):
    if len(set(y)) == 1:
        return list(set(y))[0]  # pure class
    if not attributes:
        return Counter(y).most_common(1)[0][0]  # majority class
    
    # choose attribute with max info gain
    gains = [information_gain([row[attr] for row in X], y) for attr in attributes]
    best_attr = attributes[np.argmax(gains)]
    
    tree = {best_attr: {}}
    values = set(row[best_attr] for row in X)
    
    for v in values:
        sub_X = [row for i,row in enumerate(X) if row[best_attr] == v]
        sub_y = [y[i] for i,row in enumerate(X) if row[best_attr] == v]
        if not sub_X:
            tree[best_attr][v] = Counter(y).most_common(1)[0][0]
        else:
            new_attrs = [a for a in attributes if a != best_attr]
            tree[best_attr][v] = id3(sub_X, sub_y, new_attrs)
    return tree

# =====================
# C4.5 Algorithm
# =====================

def c45(X, y, attributes):
    if len(set(y)) == 1:
        return list(set(y))[0]
    if not attributes:
        return Counter(y).most_common(1)[0][0]
    
    # choose attribute with max gain ratio
    ratios = [gain_ratio([row[attr] for row in X], y) for attr in attributes]
    best_attr = attributes[np.argmax(ratios)]
    
    tree = {best_attr: {}}
    values = set(row[best_attr] for row in X)
    
    for v in values:
        sub_X = [row for i,row in enumerate(X) if row[best_attr] == v]
        sub_y = [y[i] for i,row in enumerate(X) if row[best_attr] == v]
        if not sub_X:
            tree[best_attr][v] = Counter(y).most_common(1)[0][0]
        else:
            new_attrs = [a for a in attributes if a != best_attr]
            tree[best_attr][v] = c45(sub_X, sub_y, new_attrs)
    return tree

# %%
def predict(tree, sample, default=None):
    """Predict the label for one sample (dict of features)."""
    if not isinstance(tree, dict):
        return tree  # leaf node

    # get the attribute at this node
    attr = next(iter(tree))
    branches = tree[attr]

    # if sample[attr] not in branches, return majority class of this node
    value = sample.get(attr)
    if value not in branches:
        # majority class fallback
        leaves = []
        def collect_labels(subtree):
            if isinstance(subtree, dict):
                for v in subtree.values():
                    collect_labels(v)
            else:
                leaves.append(subtree)
        collect_labels(branches)
        return Counter(leaves).most_common(1)[0][0]

    return predict(branches[value], sample, default)

# %%
df = pd.read_csv('drug_200.csv')
display(df.head())
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
features = df.drop(["Drug"], axis=1).columns.tolist()
X = df.drop(["Drug"], axis=1).to_dict("records")   # list of dicts
y = df["Drug"].tolist()

# %%
X
# Out:
# [{'Age': 23,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 25.355},
#  {'Age': 47,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.093},
#  {'Age': 47,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.114},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 7.798},
#  {'Age': 61,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.043},
#  {'Age': 22,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 8.607},
#  {'Age': 49,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 16.275},
#  {'Age': 41,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.037},
#  {'Age': 60,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.171},
#  {'Age': 43,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 19.368},
#  {'Age': 47,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.767},
#  {'Age': 34,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 19.199},
#  {'Age': 43,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.376},
#  {'Age': 74,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 20.942},
#  {'Age': 50,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.703},
#  {'Age': 16,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 15.516},
#  {'Age': 69,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.455},
#  {'Age': 43,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.972},
#  {'Age': 23, 'Sex': 'M', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 7.298},
#  {'Age': 32,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 25.974},
#  {'Age': 57,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 19.128},
#  {'Age': 63,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 25.917},
#  {'Age': 47,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 30.568},
#  {'Age': 48,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.036},
#  {'Age': 33,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 33.486},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 18.809},
#  {'Age': 31,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 30.366},
#  {'Age': 49,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.381},
#  {'Age': 39,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 22.697},
#  {'Age': 45,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 17.951},
#  {'Age': 18,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.75},
#  {'Age': 74,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.567},
#  {'Age': 49,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.014},
#  {'Age': 65,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 31.876},
#  {'Age': 53,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 14.133},
#  {'Age': 46,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 7.285},
#  {'Age': 32,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.445},
#  {'Age': 39,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 13.938},
#  {'Age': 39,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.709},
#  {'Age': 15,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.084},
#  {'Age': 73,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 19.221},
#  {'Age': 58,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 14.239},
#  {'Age': 50,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 15.79},
#  {'Age': 23,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.26},
#  {'Age': 50,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.295},
#  {'Age': 66,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.107},
#  {'Age': 37,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.091},
#  {'Age': 68,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.291},
#  {'Age': 23,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 31.686},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 19.796},
#  {'Age': 58,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 19.416},
#  {'Age': 67,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.898},
#  {'Age': 62,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 27.183},
#  {'Age': 24,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 18.457},
#  {'Age': 68,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.189},
#  {'Age': 26, 'Sex': 'F', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 14.16},
#  {'Age': 65,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.34},
#  {'Age': 40,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 27.826},
#  {'Age': 60,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.091},
#  {'Age': 34,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.703},
#  {'Age': 38,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 29.875},
#  {'Age': 24,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.475},
#  {'Age': 67,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 20.693},
#  {'Age': 45,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.37},
#  {'Age': 60,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.303},
#  {'Age': 68,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 27.05},
#  {'Age': 29,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.856},
#  {'Age': 17,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.832},
#  {'Age': 54,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 24.658},
#  {'Age': 18,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 24.276},
#  {'Age': 70,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.967},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 19.675},
#  {'Age': 24,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.605},
#  {'Age': 41,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 22.905},
#  {'Age': 31,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 17.069},
#  {'Age': 26,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 20.909},
#  {'Age': 36,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.198},
#  {'Age': 26,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 19.161},
#  {'Age': 19,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.313},
#  {'Age': 32,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.84},
#  {'Age': 60,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.934},
#  {'Age': 64,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 7.761},
#  {'Age': 32, 'Sex': 'F', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 9.712},
#  {'Age': 38,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.326},
#  {'Age': 47,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.067},
#  {'Age': 59,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.935},
#  {'Age': 51,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.597},
#  {'Age': 69,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.478},
#  {'Age': 37,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 23.091},
#  {'Age': 50,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 17.211},
#  {'Age': 62,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 16.594},
#  {'Age': 41,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 15.156},
#  {'Age': 29,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 29.45},
#  {'Age': 42,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 29.271},
#  {'Age': 56,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.015},
#  {'Age': 36,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.424},
#  {'Age': 58,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 38.247},
#  {'Age': 56,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 25.395},
#  {'Age': 20,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 35.639},
#  {'Age': 15,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 16.725},
#  {'Age': 31,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.871},
#  {'Age': 45,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.854},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.127},
#  {'Age': 56,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 8.966},
#  {'Age': 22,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 28.294},
#  {'Age': 37,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.968},
#  {'Age': 22,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.953},
#  {'Age': 42,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 20.013},
#  {'Age': 72,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.677},
#  {'Age': 23,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 16.85},
#  {'Age': 50, 'Sex': 'M', 'BP': 'HIGH', 'Cholesterol': 'HIGH', 'Na_to_K': 7.49},
#  {'Age': 47,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 6.683},
#  {'Age': 35,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.17},
#  {'Age': 65,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 13.769},
#  {'Age': 20,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.281},
#  {'Age': 51,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.295},
#  {'Age': 67,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.514},
#  {'Age': 40,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.103},
#  {'Age': 32,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.292},
#  {'Age': 61,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 25.475},
#  {'Age': 28,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 27.064},
#  {'Age': 15,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 17.206},
#  {'Age': 34,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 22.456},
#  {'Age': 36,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 16.753},
#  {'Age': 53,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.495},
#  {'Age': 19,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 25.969},
#  {'Age': 66,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 16.347},
#  {'Age': 35,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 7.845},
#  {'Age': 47,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 33.542},
#  {'Age': 32,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 7.477},
#  {'Age': 70,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 20.489},
#  {'Age': 52,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 32.922},
#  {'Age': 49,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 13.598},
#  {'Age': 24,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 25.786},
#  {'Age': 42,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 21.036},
#  {'Age': 74,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.939},
#  {'Age': 55,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.977},
#  {'Age': 35,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.894},
#  {'Age': 51,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.343},
#  {'Age': 69,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.065},
#  {'Age': 49,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 6.269},
#  {'Age': 64,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 25.741},
#  {'Age': 60,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.621},
#  {'Age': 74,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 15.436},
#  {'Age': 39,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.664},
#  {'Age': 61,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.443},
#  {'Age': 37,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.006},
#  {'Age': 26,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.307},
#  {'Age': 61,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 7.34},
#  {'Age': 22, 'Sex': 'M', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 8.151},
#  {'Age': 49,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 8.7},
#  {'Age': 68,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.009},
#  {'Age': 55,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 7.261},
#  {'Age': 72,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 14.642},
#  {'Age': 37,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 16.724},
#  {'Age': 49,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.537},
#  {'Age': 31,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.227},
#  {'Age': 53,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 22.963},
#  {'Age': 59,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.444},
#  {'Age': 34,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.923},
#  {'Age': 30,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.443},
#  {'Age': 57,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 9.945},
#  {'Age': 43,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.859},
#  {'Age': 21,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 28.632},
#  {'Age': 16,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 19.007},
#  {'Age': 38,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.295},
#  {'Age': 58,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 26.645},
#  {'Age': 57,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 14.216},
#  {'Age': 51,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 23.003},
#  {'Age': 20,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.262},
#  {'Age': 28,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.879},
#  {'Age': 45,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.017},
#  {'Age': 39,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 17.225},
#  {'Age': 41,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 18.739},
#  {'Age': 42,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 12.766},
#  {'Age': 73,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.348},
#  {'Age': 48,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 10.446},
#  {'Age': 25,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 19.011},
#  {'Age': 39,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.969},
#  {'Age': 67,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 15.891},
#  {'Age': 22,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 22.818},
#  {'Age': 59,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 13.884},
#  {'Age': 20,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.686},
#  {'Age': 36,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 15.49},
#  {'Age': 18,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 37.188},
#  {'Age': 57,
#   'Sex': 'F',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 25.893},
#  {'Age': 70,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.849},
#  {'Age': 47,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 10.403},
#  {'Age': 65,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 34.997},
#  {'Age': 64,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 20.932},
#  {'Age': 58,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 18.991},
#  {'Age': 23,
#   'Sex': 'M',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 8.011},
#  {'Age': 72, 'Sex': 'M', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 16.31},
#  {'Age': 72, 'Sex': 'M', 'BP': 'LOW', 'Cholesterol': 'HIGH', 'Na_to_K': 6.769},
#  {'Age': 46,
#   'Sex': 'F',
#   'BP': 'HIGH',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 34.686},
#  {'Age': 56,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 11.567},
#  {'Age': 16,
#   'Sex': 'M',
#   'BP': 'LOW',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 12.006},
#  {'Age': 52,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'HIGH',
#   'Na_to_K': 9.894},
#  {'Age': 23,
#   'Sex': 'M',
#   'BP': 'NORMAL',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 14.02},
#  {'Age': 40,
#   'Sex': 'F',
#   'BP': 'LOW',
#   'Cholesterol': 'NORMAL',
#   'Na_to_K': 11.349}]

# %%
y
# Out:
# ['drugY',
#  'drugC',
#  'drugC',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugC',
#  'drugY',
#  'drugY',
#  'drugC',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugA',
#  'drugC',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugB',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugX',
#  'drugA',
#  'drugX',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugB',
#  'drugY',
#  'drugX',
#  'drugX',
#  'drugX',
#  'drugA',
#  'drugC',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugB',
#  'drugC',
#  'drugB',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugA',
#  'drugY',
#  'drugX',
#  'drugB',
#  'drugY',
#  'drugA',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugB',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugA',
#  'drugY',
#  'drugA',
#  'drugX',
#  'drugB',
#  'drugX',
#  'drugC',
#  'drugA',
#  'drugC',
#  'drugB',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugA',
#  'drugA',
#  'drugC',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugB',
#  'drugY',
#  'drugA',
#  'drugX',
#  'drugX',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugX',
#  'drugA',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugB',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugB',
#  'drugA',
#  'drugB',
#  'drugX',
#  'drugA',
#  'drugY',
#  'drugB',
#  'drugY',
#  'drugA',
#  'drugX',
#  'drugX',
#  'drugA',
#  'drugX',
#  'drugC',
#  'drugA',
#  'drugB',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugC',
#  'drugA',
#  'drugY',
#  'drugC',
#  'drugX',
#  'drugX',
#  'drugB',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugY',
#  'drugA',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugA',
#  'drugY',
#  'drugA',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugX',
#  'drugX',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugB',
#  'drugA',
#  'drugY',
#  'drugY',
#  'drugY',
#  'drugA',
#  'drugY',
#  'drugC',
#  'drugY',
#  'drugC',
#  'drugC',
#  'drugX',
#  'drugX',
#  'drugX']

# %%
# =====================
# Cross Validation
# =====================

def evaluate(X, y, algorithm_func):
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    metrics = {"accuracy": [], "f1": [], "precision": [], "recall": []}
    
    for train_idx, test_idx in kf.split(X):
        X_train, X_test = [X[i] for i in train_idx], [X[i] for i in test_idx]
        y_train, y_test = [y[i] for i in train_idx], [y[i] for i in test_idx]
        
        attributes = list(X[0].keys())
        tree = algorithm_func(X_train, y_train, attributes)
        
        y_pred = [predict(tree, sample) for sample in X_test]
        
        metrics["accuracy"].append((accuracy_score(y_test, y_pred)))
        metrics["f1"].append(f1_score(y_test, y_pred, average="macro", zero_division=0))
        metrics["precision"].append(precision_score(y_test, y_pred, average="macro", zero_division=0))
        metrics["recall"].append(recall_score(y_test, y_pred, average="macro", zero_division=0))
    
    return {k: round(np.mean(v),4) for k,v in metrics.items()}

# %%
id3_tree = id3(X,y, features)
print("=== ID3 Tree ===")
print(id3_tree)
# Out:
# === ID3 Tree ===
# {'Na_to_K': {6.683: 'drugX', 7.798: 'drugX', 8.607: 'drugX', 7.298: 'drugC', 10.114: 'drugC', 11.037: 'drugC', 11.767: 'drugC', 13.972: 'drugA', 13.093: 'drugC', 12.703: 'drugX', 15.171: 'drugY', 16.275: 'drugY', 15.376: 'drugY', 18.043: 'drugY', 19.368: 'drugY', 19.199: 'drugY', 20.942: 'drugY', 15.516: 'drugY', 19.128: 'drugY', 25.355: 'drugY', 25.974: 'drugY', 25.917: 'drugY', 22.697: 'drugY', 27.183: 'drugY', 30.568: 'drugY', 30.366: 'drugY', 31.876: 'drugY', 33.486: 'drugY', 31.686: 'drugY', 27.826: 'drugY', 29.875: 'drugY', 29.45: 'drugY', 29.271: 'drugY', 38.247: 'drugY', 35.639: 'drugY', 8.75: 'drugX', 8.107: 'drugX', 37.188: 'drugY', 9.381: 'drugX', 9.567: 'drugB', 9.445: 'drugA', 9.677: 'drugB', 9.945: 'drugB', 10.189: 'drugB', 10.832: 'drugX', 10.067: 'drugC', 11.198: 'drugA', 11.326: 'drugA', 11.424: 'drugX', 11.939: 'drugX', 11.009: 'drugB', 12.854: 'drugA', 12.006: {'Age': {16: 'drugC', 37: 'drugX'}}, 11.262: 'drugA', 11.686: 'drugX', 11.567: 'drugC', 13.884: 'drugX', 15.79: 'drugY', 15.015: 'drugY', 15.436: 'drugY', 16.594: 'drugY', 16.725: 'drugY', 16.85: 'drugY', 16.753: 'drugY', 16.347: 'drugY', 17.951: 'drugY', 17.211: 'drugY', 17.225: 'drugY', 18.457: 'drugY', 18.295: 'drugY', 18.348: 'drugY', 18.991: 'drugY', 19.796: 'drugY', 19.161: 'drugY', 7.845: 'drugX', 20.909: 'drugY', 21.036: 'drugY', 22.905: 'drugY', 22.963: 'drugY', 23.091: 'drugY', 23.003: 'drugY', 24.658: 'drugY', 25.475: 'drugY', 25.969: 'drugY', 25.786: 'drugY', 25.741: 'drugY', 25.893: 'drugY', 27.064: 'drugY', 6.269: 'drugA', 6.769: 'drugC', 32.922: 'drugY', 33.542: 'drugY', 8.37: 'drugX', 34.997: 'drugY', 34.686: 'drugY', 9.281: 'drugX', 9.443: 'drugX', 9.894: 'drugX', 10.065: 'drugX', 10.537: 'drugC', 10.443: 'drugX', 10.446: 'drugA', 10.403: 'drugA', 11.455: 'drugX', 12.26: 'drugX', 12.495: 'drugB', 12.894: 'drugA', 12.879: 'drugX', 12.766: 'drugA', 13.967: 'drugB', 13.934: 'drugB', 13.769: 'drugX', 13.598: 'drugX', 15.156: 'drugY', 15.891: 'drugY', 7.285: 'drugX', 7.477: 'drugX', 7.34: 'drugX', 8.968: 'drugX', 8.151: 'drugC', 8.7: 'drugA', 8.011: 'drugA', 9.709: 'drugX', 9.084: 'drugX', 9.712: 'drugC', 9.514: 'drugX', 9.849: 'drugB', 10.291: 'drugC', 10.898: 'drugX', 10.605: 'drugX', 10.84: 'drugX', 10.977: 'drugB', 11.014: 'drugX', 11.34: 'drugB', 11.953: 'drugX', 11.343: 'drugB', 11.227: 'drugA', 11.349: 'drugX', 13.303: 'drugB', 14.133: 'drugX', 14.239: 'drugB', 14.16: 'drugC', 14.642: 'drugX', 14.02: 'drugX', 16.724: 'drugY', 16.31: 'drugY', 17.069: 'drugY', 17.206: 'drugY', 18.809: 'drugY', 18.703: 'drugY', 18.739: 'drugY', 19.221: 'drugY', 19.416: 'drugY', 19.675: 'drugY', 19.007: 'drugY', 7.761: 'drugX', 20.693: 'drugY', 20.013: 'drugY', 20.489: 'drugY', 7.261: 'drugX', 19.011: 'drugY', 20.932: 'drugY', 22.456: 'drugY', 22.818: 'drugY', 24.276: 'drugY', 25.395: 'drugY', 26.645: 'drugY', 27.05: 'drugY', 10.017: 'drugX', 28.294: 'drugY', 28.632: 'drugY', 7.49: 'drugA', 8.966: 'drugX', 8.621: 'drugB', 9.475: 'drugA', 9.17: 'drugX', 9.664: 'drugA', 10.091: 'drugX', 10.103: 'drugX', 10.292: 'drugA', 10.444: 'drugC', 11.871: 'drugA', 12.295: 'drugX', 12.856: 'drugA', 12.307: 'drugA', 12.923: 'drugX', 12.859: 'drugX', 13.938: 'drugX', 13.091: 'drugA', 13.313: 'drugA', 13.935: 'drugB', 13.597: 'drugX', 13.127: 'drugC', 14.216: 'drugX', 15.036: 'drugY', 15.478: 'drugY', 15.969: 'drugY', 15.49: 'drugY'}}

# %%
c45_tree = c45(X,y, features)
print("=== ID3 Tree ===")
print(c45_tree)
# Out:
# === ID3 Tree ===
# {'BP': {'NORMAL': {'Na_to_K': {6.683: 'drugX', 7.798: 'drugX', 8.607: 'drugX', 9.381: 'drugX', 8.75: 'drugX', 7.285: 'drugX', 12.703: 'drugX', 9.709: 'drugX', 14.133: 'drugX', 15.171: 'drugY', 16.275: 'drugY', 9.084: 'drugX', 15.79: 'drugY', 19.221: 'drugY', 12.26: 'drugX', 12.295: 'drugX', 19.675: 'drugY', 22.905: 'drugY', 24.658: 'drugY', 25.917: 'drugY', 17.211: 'drugY', 27.05: 'drugY', 27.064: 'drugY', 22.456: 'drugY', 25.786: 'drugY', 31.686: 'drugY', 25.893: 'drugY', 7.477: 'drugX', 8.107: 'drugX', 8.966: 'drugX', 9.281: 'drugX', 9.514: 'drugX', 9.443: 'drugX', 9.894: 'drugX', 10.898: 'drugX', 10.091: 'drugX', 10.832: 'drugX', 10.605: 'drugX', 10.103: 'drugX', 11.953: 'drugX', 10.065: 'drugX', 10.443: 'drugX', 12.859: 'drugX', 12.879: 'drugX', 13.597: 'drugX', 13.884: 'drugX', 14.216: 'drugX', 14.02: 'drugX', 15.969: 'drugY', 15.891: 'drugY', 16.594: 'drugY', 16.85: 'drugY', 16.753: 'drugY', 17.225: 'drugY', 19.011: 'drugY', 7.761: 'drugX', 7.845: 'drugX', 20.489: 'drugY', 7.261: 'drugX'}}, 'HIGH': {'Na_to_K': {6.269: 'drugA', 7.49: 'drugA', 8.621: 'drugB', 9.567: 'drugB', 9.445: 'drugA', 10.189: 'drugB', 11.34: 'drugB', 13.972: 'drugA', 14.239: 'drugB', 15.516: 'drugY', 13.091: 'drugA', 9.475: 'drugA', 18.809: 'drugY', 19.199: 'drugY', 19.416: 'drugY', 18.457: 'drugY', 18.703: 'drugY', 17.069: 'drugY', 24.276: 'drugY', 25.969: 'drugY', 25.355: 'drugY', 25.974: 'drugY', 27.826: 'drugY', 23.091: 'drugY', 30.366: 'drugY', 31.876: 'drugY', 29.45: 'drugY', 25.395: 'drugY', 28.294: 'drugY', 35.639: 'drugY', 28.632: 'drugY', 37.188: 'drugY', 34.997: 'drugY', 34.686: 'drugY', 9.677: 'drugB', 9.945: 'drugB', 11.198: 'drugA', 11.326: 'drugA', 11.009: 'drugB', 11.262: 'drugA', 12.854: 'drugA', 15.436: 'drugY', 16.725: 'drugY', 16.347: 'drugY', 18.295: 'drugY', 18.348: 'drugY', 18.991: 'drugY', 19.161: 'drugY', 21.036: 'drugY', 25.475: 'drugY', 10.446: 'drugA', 10.403: 'drugA', 12.495: 'drugB', 12.894: 'drugA', 12.766: 'drugA', 13.967: 'drugB', 13.934: 'drugB', 15.156: 'drugY', 8.7: 'drugA', 8.011: 'drugA', 9.849: 'drugB', 10.977: 'drugB', 11.343: 'drugB', 11.227: 'drugA', 13.303: 'drugB', 17.206: 'drugY', 19.007: 'drugY', 20.932: 'drugY', 22.818: 'drugY', 9.664: 'drugA', 10.292: 'drugA', 11.871: 'drugA', 12.856: 'drugA', 12.307: 'drugA', 13.313: 'drugA', 13.935: 'drugB', 15.49: 'drugY'}}, 'LOW': {'Cholesterol': {'NORMAL': {'Na_to_K': {7.34: 'drugX', 8.37: 'drugX', 8.968: 'drugX', 10.84: 'drugX', 11.455: 'drugX', 11.014: 'drugX', 13.938: 'drugX', 11.424: 'drugX', 9.17: 'drugX', 13.769: 'drugX', 13.598: 'drugX', 11.939: 'drugX', 19.128: 'drugY', 19.368: 'drugY', 20.693: 'drugY', 22.697: 'drugY', 20.909: 'drugY', 16.724: 'drugY', 25.741: 'drugY', 23.003: 'drugY', 27.183: 'drugY', 29.271: 'drugY', 29.875: 'drugY', 30.568: 'drugY', 32.922: 'drugY', 33.542: 'drugY', 10.017: 'drugX', 11.686: 'drugX', 11.349: 'drugX', 12.006: 'drugX', 12.923: 'drugX', 14.642: 'drugX', 18.739: 'drugY'}}, 'HIGH': {'Na_to_K': {6.769: 'drugC', 7.298: 'drugC', 8.151: 'drugC', 9.712: 'drugC', 10.114: 'drugC', 11.037: 'drugC', 11.767: 'drugC', 13.093: 'drugC', 10.291: 'drugC', 15.376: 'drugY', 15.036: 'drugY', 17.951: 'drugY', 18.043: 'drugY', 19.796: 'drugY', 20.942: 'drugY', 14.16: 'drugC', 15.478: 'drugY', 15.015: 'drugY', 20.013: 'drugY', 22.963: 'drugY', 18.295: 'drugY', 26.645: 'drugY', 33.486: 'drugY', 38.247: 'drugY', 10.067: 'drugC', 10.537: 'drugC', 10.444: 'drugC', 11.567: 'drugC', 12.006: 'drugC', 13.127: 'drugC', 16.31: 'drugY'}}}}}}

# %%
print("ID3 CV Results:", evaluate(X, y, id3))
print("C4.5 CV Results:", evaluate(X, y, c45))
print("-------------------------")
# Out:
# ID3 CV Results: {'accuracy': np.float64(0.455), 'f1': np.float64(0.1328), 'precision': np.float64(0.0976), 'recall': np.float64(0.21)}
# C4.5 CV Results: {'accuracy': np.float64(0.52), 'f1': np.float64(0.3503), 'precision': np.float64(0.3035), 'recall': np.float64(0.4705)}
# -------------------------

# %%
for x in X:
    print(predict(id3_tree,x))

metrics = {"accuracy": [], "f1": [], "precision": [], "recall": []}
        
y_pred = [predict(id3_tree, sample) for sample in X]
        
metrics["accuracy"].append((accuracy_score(y, y_pred)))
metrics["f1"].append(f1_score(y, y_pred, average="macro", zero_division=0))
metrics["precision"].append(precision_score(y, y_pred, average="macro", zero_division=0))
metrics["recall"].append(recall_score(y, y_pred, average="macro", zero_division=0))

print(metrics)
# Out:
# drugY
# drugC
# drugC
# drugX
# drugY
# drugX
# drugY
# drugC
# drugY
# drugY
# drugC
# drugY
# drugY
# drugY
# drugX
# drugY
# drugX
# drugA
# drugC
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugX
# drugB
# drugX
# drugY
# drugX
# drugX
# drugA
# drugX
# drugX
# drugX
# drugY
# drugB
# drugY
# drugX
# drugX
# drugX
# drugA
# drugC
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugB
# drugC
# drugB
# drugY
# drugX
# drugY
# drugY
# drugA
# drugY
# drugX
# drugB
# drugY
# drugA
# drugX
# drugY
# drugY
# drugB
# drugY
# drugX
# drugY
# drugY
# drugY
# drugA
# drugY
# drugA
# drugX
# drugB
# drugX
# drugC
# drugA
# drugC
# drugB
# drugX
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugY
# drugY
# drugA
# drugA
# drugC
# drugX
# drugY
# drugX
# drugX
# drugY
# drugB
# drugY
# drugA
# drugX
# drugX
# drugX
# drugX
# drugY
# drugX
# drugX
# drugA
# drugY
# drugY
# drugY
# drugY
# drugY
# drugB
# drugY
# drugY
# drugX
# drugY
# drugX
# drugY
# drugY
# drugX
# drugY
# drugY
# drugX
# drugB
# drugA
# drugB
# drugX
# drugA
# drugY
# drugB
# drugY
# drugA
# drugX
# drugX
# drugA
# drugX
# drugC
# drugA
# drugB
# drugX
# drugX
# drugY
# drugC
# drugA
# drugY
# drugC
# drugX
# drugX
# drugB
# drugX
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugA
# drugX
# drugX
# drugY
# drugY
# drugA
# drugY
# drugA
# drugY
# drugY
# drugY
# drugY
# drugX
# drugX
# drugY
# drugY
# drugY
# drugB
# drugA
# drugY
# drugY
# drugY
# drugA
# drugY
# drugC
# drugY
# drugC
# drugC
# drugX
# drugX
# drugX
# {'accuracy': [1.0], 'f1': [1.0], 'precision': [1.0], 'recall': [1.0]}

# %%
for x in X:
    print(predict(c45_tree,x))


metrics = {"accuracy": [], "f1": [], "precision": [], "recall": []}
        
y_pred = [predict(c45_tree, sample) for sample in X]
        
metrics["accuracy"].append((accuracy_score(y, y_pred)))
metrics["f1"].append(f1_score(y, y_pred, average="macro", zero_division=0))
metrics["precision"].append(precision_score(y, y_pred, average="macro", zero_division=0))
metrics["recall"].append(recall_score(y, y_pred, average="macro", zero_division=0))

print(metrics)
# Out:
# drugY
# drugC
# drugC
# drugX
# drugY
# drugX
# drugY
# drugC
# drugY
# drugY
# drugC
# drugY
# drugY
# drugY
# drugX
# drugY
# drugX
# drugA
# drugC
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugX
# drugB
# drugX
# drugY
# drugX
# drugX
# drugA
# drugX
# drugX
# drugX
# drugY
# drugB
# drugY
# drugX
# drugX
# drugX
# drugA
# drugC
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugB
# drugC
# drugB
# drugY
# drugX
# drugY
# drugY
# drugA
# drugY
# drugX
# drugB
# drugY
# drugA
# drugX
# drugY
# drugY
# drugB
# drugY
# drugX
# drugY
# drugY
# drugY
# drugA
# drugY
# drugA
# drugX
# drugB
# drugX
# drugC
# drugA
# drugC
# drugB
# drugX
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugY
# drugY
# drugY
# drugA
# drugA
# drugC
# drugX
# drugY
# drugX
# drugX
# drugY
# drugB
# drugY
# drugA
# drugX
# drugX
# drugX
# drugX
# drugY
# drugX
# drugX
# drugA
# drugY
# drugY
# drugY
# drugY
# drugY
# drugB
# drugY
# drugY
# drugX
# drugY
# drugX
# drugY
# drugY
# drugX
# drugY
# drugY
# drugX
# drugB
# drugA
# drugB
# drugX
# drugA
# drugY
# drugB
# drugY
# drugA
# drugX
# drugX
# drugA
# drugX
# drugC
# drugA
# drugB
# drugX
# drugX
# drugY
# drugC
# drugA
# drugY
# drugC
# drugX
# drugX
# drugB
# drugX
# drugY
# drugY
# drugY
# drugY
# drugX
# drugY
# drugA
# drugX
# drugX
# drugY
# drugY
# drugA
# drugY
# drugA
# drugY
# drugY
# drugY
# drugY
# drugX
# drugX
# drugY
# drugY
# drugY
# drugB
# drugA
# drugY
# drugY
# drugY
# drugA
# drugY
# drugC
# drugY
# drugC
# drugC
# drugX
# drugX
# drugX
# {'accuracy': [1.0], 'f1': [1.0], 'precision': [1.0], 'recall': [1.0]}
